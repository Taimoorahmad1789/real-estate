# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Islamadad_properties_cleaned_v2.csv')

# %%
df.head()
# Out:
#   property_type                 society     location  \
# 0          flat  DHA Phase 1 Apartments  DHA Phase 1
# 1          flat          G-15 Residency         G-15
# 2          flat     Bahria Town Heights  Bahria Town
# 3          flat              G-12 Homes         G-12
# 4          flat              G-12 Plaza         G-12
#
#                        areaWithType    area  bedRoom  bathroom  balcony  \
# 0    Carpet area: 791 (73.49 sq.m.)   793.0        2         2        1
# 1    Carpet area: 870 (80.83 sq.m.)   870.0        2         2        3
# 2    Carpet area: 946 (87.89 sq.m.)   947.0        3         3        2
# 3  Carpet area: 1321 (122.72 sq.m.)  1322.0        3         4        3
# 4    Carpet area: 354 (32.89 sq.m.)   356.0        1         1        1
#
#    floorNum      facing       agePossession  price_per_sqft  price_in_crore  \
# 0         3  North-East      Moderately Old         23596.0            1.87
# ...

# %%
df.value_counts().sum()
# Out:
# 0

# %%
sns.histplot(df['price_in_crore'],kde= True)
# Out:
# <Axes: xlabel='price_in_crore', ylabel='Count'>

# %%
sns.boxplot(x=df['price_in_crore'])
# Out:
# <Axes: xlabel='price_in_crore'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_in_crore'].quantile(0.25)
Q3 = df['price_in_crore'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price_in_crore'] < lower_bound) | (df['price_in_crore'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price_in_crore'].describe()

num_outliers, outliers_price_stats
# Out:
# (241,
#  count    241.000000
#  mean       7.202905
#  std        2.297291
#  min        5.000000
#  25%        5.580000
#  50%        6.470000
#  75%        7.970000
#  max       18.210000
#  Name: price_in_crore, dtype: float64)

# %%
outliers.sort_values('price_in_crore',ascending=False).head(20)
# Out:
#      property_type             society     location  \
# 1789         house       g-6 residency          G-6
# 1379         house         e-7 heights          E-7
# 1911         house         f-11 villas         F-11
# 2979         house         f-7 enclave          F-7
# 1893         house          f-6 villas          F-6
# 529          house       f-8 residency          F-8
# 2540         house         f-6 heights          F-6
# 1085         house       f-7 residency          F-7
# 3772         house         f-11 villas         F-11
# 2303         house        f-11 enclave         F-11
# 3777         house          f-5 villas          F-5
# 3048         house          f-7 villas          F-7
# 3861         house       f-8 residency          F-8
# 2507         house          g-6 villas          G-6
# 3313         house         f-6 enclave          F-6
# 3876         house        g-14 heights         G-14
# 2635         house         f-7 gardens          F-7
# ...

# %%
sns.histplot(df['price_per_sqft'],kde =True)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df['built_up_area'].sample(50)
# Out:
# 1153       NaN
# 234        NaN
# 1178    2440.0
# 3950       NaN
# 1849       NaN
# 231        NaN
# 2111       NaN
# 2189       NaN
# 471        NaN
# 91      1457.0
# 3818    1892.0
# 2829       NaN
# 3897       NaN
# 3480       NaN
# 358        NaN
# 2822       NaN
# 2921       NaN
# 2242       NaN
# 1927       NaN
# 3170       NaN
# 2719     700.0
# 2125       NaN
# 3440       NaN
# 99         NaN
# 2211       NaN
# 2743    2866.0
# 406        NaN
# 1343       NaN
# 2397       NaN
# 3251       NaN
# 1459       NaN
# 2813       NaN
# 209        NaN
# 2644       NaN
# 421        NaN
# 2524       NaN
# 3896       NaN
# 1090       NaN
# 3136    1596.0
# 2725       NaN
# 2875       NaN
# 1851     927.0
# 1283       NaN
# 2234       NaN
# 3321       NaN
# 654        NaN
# 3929       NaN
# 3904       NaN
# 1687       NaN
# 825        NaN
# Name: built_up_area, dtype: float64

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (113,
#  count      113.000000
#  mean     49164.247788
#  std       6138.998324
#  min      39850.000000
#  25%      44126.000000
#  50%      48589.000000
#  75%      54132.000000
#  max      59693.000000
#  Name: price_per_sqft, dtype: float64)

# %%
df['built_up_area'].sample(50)
# Out:
# 1848       NaN
# 705      800.0
# 3346       NaN
# 4039    2300.0
# 1215       NaN
# 3083       NaN
# 3992       NaN
# 335        NaN
# 731        NaN
# 2113       NaN
# 410        NaN
# 2514       NaN
# 3230       NaN
# 2697       NaN
# 2835       NaN
# 1873    1742.0
# 3880       NaN
# 3164       NaN
# 3107       NaN
# 2234       NaN
# 1945       NaN
# 2575       NaN
# 911     1851.0
# 3709     800.0
# 2023       NaN
# 455      700.0
# 2003    1471.0
# 154     2081.0
# 1960       NaN
# 3973       NaN
# 1713       NaN
# 3211       NaN
# 874        NaN
# 579        NaN
# 366        NaN
# 2747       NaN
# 1677     700.0
# 563     1173.0
# 2143       NaN
# 254        NaN
# 3469       NaN
# 1437       NaN
# 1951       NaN
# 448        NaN
# 1681     600.0
# 836        NaN
# 2091       NaN
# 2028       NaN
# 1654    1839.0
# 1606       NaN
# Name: built_up_area, dtype: float64

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x <1000 else x )
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\573678382.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x <1000 else x )

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price_in_crore']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\738830076.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price_in_crore']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      113.000000
# mean     32082.831858
# std      21873.097405
# min       4427.000000
# 25%       5738.000000
# 50%      41993.000000
# 75%      49628.000000
# max      59701.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\2451507319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
df['built_up_area'].sample(50)
# Out:
# 3777    4636.0
# 3112       NaN
# 3503    1474.0
# 189        NaN
# 3033    1608.0
# 2221    1002.0
# 3154       NaN
# 3689       NaN
# 3791       NaN
# 281        NaN
# 1556       NaN
# 1006       NaN
# 2721       NaN
# 2576       NaN
# 687        NaN
# 2302    1078.0
# 612        NaN
# 2639       NaN
# 2673       NaN
# 1291       NaN
# 2125       NaN
# 818        NaN
# 1948       NaN
# 3998       NaN
# 2894       NaN
# 1863    1356.0
# 293        NaN
# 2678    1491.0
# 8          NaN
# 2860       NaN
# 182        NaN
# 3433       NaN
# 1191       NaN
# 1323       NaN
# 266        NaN
# 3007     872.0
# 114        NaN
# 1460       NaN
# 1136       NaN
# 2278     700.0
# 3002       NaN
# 3852       NaN
# 1883       NaN
# 2143       NaN
# 2082    2599.0
# 2747       NaN
# 3037       NaN
# 1891       NaN
# 4049       NaN
# 2773       NaN
# Name: built_up_area, dtype: float64

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000].shape
# Out:
# (46, 22)

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df['built_up_area'].sample(50)
# Out:
# 2075       NaN
# 229        NaN
# 2283       NaN
# 2872       NaN
# 2260       NaN
# 1329       NaN
# 3956    1179.0
# 3320     700.0
# 2363       NaN
# 2542    2226.0
# 2410    2727.0
# 3663       NaN
# 883        NaN
# 3053    1070.0
# 2849     726.0
# 1756    2068.0
# 3675       NaN
# 3757       NaN
# 2767       NaN
# 3682       NaN
# 134        NaN
# 2291       NaN
# 3258       NaN
# 2781    1796.0
# 209        NaN
# 1216     974.0
# 495        NaN
# 1788       NaN
# 851        NaN
# 1505       NaN
# 3965       NaN
# 2840       NaN
# 2971    2250.0
# 560        NaN
# 928        NaN
# 1359       NaN
# 4007       NaN
# 1998       NaN
# 2208       NaN
# 2122       NaN
# 3518    1985.0
# 573      800.0
# 153     2306.0
# 2079    2688.0
# 956        NaN
# 3847       NaN
# 2882       NaN
# 619     2538.0
# 1138       NaN
# 1043       NaN
# Name: built_up_area, dtype: float64

# %%
df.head()
# Out:
#   property_type                 society     location  \
# 0          flat  DHA Phase 1 Apartments  DHA Phase 1
# 1          flat          G-15 Residency         G-15
# 2          flat     Bahria Town Heights  Bahria Town
# 3          flat              G-12 Homes         G-12
# 4          flat              G-12 Plaza         G-12
#
#                        areaWithType    area  bedRoom  bathroom  balcony  \
# 0    Carpet area: 791 (73.49 sq.m.)   793.0        2         2        1
# 1    Carpet area: 870 (80.83 sq.m.)   870.0        2         2        3
# 2    Carpet area: 946 (87.89 sq.m.)   947.0        3         3        2
# 3  Carpet area: 1321 (122.72 sq.m.)  1322.0        3         4        3
# 4    Carpet area: 354 (32.89 sq.m.)   356.0        1         1        1
#
#    floorNum      facing       agePossession  price_per_sqft  price_in_crore  \
# 0         3  North-East      Moderately Old         23596.0            1.87
# ...

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\4282079938.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count    4008.000000
# mean     1093.172405
# std       608.062851
# min       346.000000
# 25%       700.000000
# 50%       977.000000
# 75%      1330.000000
# max      6423.000000
# Name: area, dtype: float64

# %%
df[df['area']>4500].shape
# Out:
# (4, 22)

# %%
df = df[df['area'] <= 4500]

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
df['built_up_area'].sample(50)
# Out:
# 1197       NaN
# 258        NaN
# 2625       NaN
# 2226     775.0
# 2385     800.0
# 2954       NaN
# 3863       NaN
# 3387       NaN
# 839        NaN
# 555      700.0
# 483        NaN
# 1928       NaN
# 3872       NaN
# 3423       NaN
# 3563    2146.0
# 1306       NaN
# 3799       NaN
# 266        NaN
# 3295       NaN
# 2133       NaN
# 4045       NaN
# 424        NaN
# 2964       NaN
# 1248       NaN
# 3529    2115.0
# 233      800.0
# 2934       NaN
# 2134       NaN
# 30         NaN
# 2050       NaN
# 3549    1973.0
# 3674     700.0
# 667        NaN
# 1524       NaN
# 3015       NaN
# 10       800.0
# 246        NaN
# 2397       NaN
# 427        NaN
# 3027    1157.0
# 1120       NaN
# 1797       NaN
# 2452       NaN
# 3196       NaN
# 1404    1359.0
# 658        NaN
# 1059    1767.0
# 2911       NaN
# 2770       NaN
# 3232       NaN
# Name: built_up_area, dtype: float64

# %%
df.shape
# Out:
# (4004, 22)

# %%
df['area'].describe()
# Out:
# count    4004.000000
# mean     1089.150350
# std       594.408805
# min       346.000000
# 25%       700.000000
# 50%       977.000000
# 75%      1329.000000
# max      4205.000000
# Name: area, dtype: float64

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    4004.000000
# mean        3.013237
# std         1.641662
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        16.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                   society        location  \
# 185          house            g-15 residency            G-15
# 2604         house              g-13 heights            G-13
# 3540         house  margalla hills residency  Margalla Hills
# 4051         house              g-10 heights            G-10
# 2220         house              g-15 enclave            G-15
# 2836         house              g-11 enclave            G-11
# 2926         house              g-10 enclave            G-10
#
#                             areaWithType    area  bedRoom  bathroom  balcony  \
# 185   Built Up area: 4045 (375.79 sq.m.)  4046.0       16        15        1
# 2604  Built Up area: 4052 (376.44 sq.m.)  4051.0       16        17        3
# 3540  Built Up area: 3689 (342.72 sq.m.)  3690.0       16        12        3
# 4051  Built Up area: 3625 (336.77 sq.m.)  3627.0       16        17        0
# 2220   Built Up area: 3734 (346.9 sq.m.)  3735.0       12        11        1
# ...

# %%
df.shape
# Out:
# (4004, 22)

# %%
df['built_up_area'].sample(50)
# Out:
# 3589       NaN
# 175        NaN
# 1693       NaN
# 3978       NaN
# 2373       NaN
# 3721       NaN
# 1070       NaN
# 1393       NaN
# 1079       NaN
# 139     2686.0
# 1372    3186.0
# 1415     800.0
# 2132       NaN
# 870        NaN
# 701        NaN
# 3750       NaN
# 1149    1021.0
# 3561       NaN
# 156      600.0
# 4018       NaN
# 1513       NaN
# 4030       NaN
# 3319       NaN
# 3267       NaN
# 887        NaN
# 3076    1229.0
# 2036    2659.0
# 503        NaN
# 1926       NaN
# 3831       NaN
# 584        NaN
# 479        NaN
# 3515       NaN
# 1089       NaN
# 1408       NaN
# 2356       NaN
# 274      975.0
# 1666       NaN
# 3501    1123.0
# 440        NaN
# 402      700.0
# 43         NaN
# 1464       NaN
# 3593       NaN
# 2430       NaN
# 1575    1103.0
# 1724       NaN
# 3287    1879.0
# 2702       NaN
# 2689     613.0
# Name: built_up_area, dtype: float64

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df.head()
# Out:
#   property_type                 society     location  \
# 0          flat  DHA Phase 1 Apartments  DHA Phase 1
# 1          flat          G-15 Residency         G-15
# 2          flat     Bahria Town Heights  Bahria Town
# 3          flat              G-12 Homes         G-12
# 4          flat              G-12 Plaza         G-12
#
#                        areaWithType    area  bedRoom  bathroom  balcony  \
# 0    Carpet area: 791 (73.49 sq.m.)   793.0        2         2        1
# 1    Carpet area: 870 (80.83 sq.m.)   870.0        2         2        3
# 2    Carpet area: 946 (87.89 sq.m.)   947.0        3         3        2
# 3  Carpet area: 1321 (122.72 sq.m.)  1322.0        3         4        3
# 4    Carpet area: 354 (32.89 sq.m.)   356.0        1         1        1
#
#    floorNum      facing       agePossession  price_per_sqft  price_in_crore  \
# 0         3  North-East      Moderately Old         23596.0            1.87
# ...

# %%
df['carpet_area'].describe()
# Out:
# count    3000.000000
# mean      919.827667
# std       373.991220
# min       350.000000
# 25%       637.000000
# 50%       905.000000
# 75%      1169.000000
# max      2441.000000
# Name: carpet_area, dtype: float64

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %%
df['built_up_area'].sample(50)
# Out:
# 3599       NaN
# 2257       NaN
# 170        NaN
# 3515       NaN
# 1583       NaN
# 3462       NaN
# 570     2105.0
# 241     1595.0
# 2460       NaN
# 4000       NaN
# 980     2485.0
# 2355       NaN
# 3821       NaN
# 3888       NaN
# 3761       NaN
# 2473       NaN
# 2450       NaN
# 3163       NaN
# 79         NaN
# 3884    1905.0
# 3169    1468.0
# 455      700.0
# 3501    1123.0
# 346        NaN
# 1829       NaN
# 2609     700.0
# 1918       NaN
# 3283       NaN
# 1348       NaN
# 885        NaN
# 3452       NaN
# 3305    1215.0
# 3416       NaN
# 10       800.0
# 483        NaN
# 2004       NaN
# 125        NaN
# 2134       NaN
# 733     1510.0
# 2928       NaN
# 1014       NaN
# 1727       NaN
# 1966       NaN
# 1411       NaN
# 3617       NaN
# 317        NaN
# 187      700.0
# 1372    3186.0
# 453      700.0
# 1067    1611.0
# Name: built_up_area, dtype: float64

# %%
sns.boxplot(x = df['luxury_score'])
# Out:
# <Axes: xlabel='luxury_score'>

# %%
df.shape
# Out:
# (4004, 22)

# %%
df['price_per_sqft'] = round((df['price_in_crore']*10000000)/df['area'])

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\SAEEDCOMPUTERS\AppData\Local\Temp\ipykernel_15388\2451507319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x = df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
sns.lmplot(data = df , x = 'area', y = 'bedRoom')

# %%
df.head()
# Out:
#   property_type                 society     location  \
# 0          flat  DHA Phase 1 Apartments  DHA Phase 1
# 1          flat          G-15 Residency         G-15
# 2          flat     Bahria Town Heights  Bahria Town
# 3          flat              G-12 Homes         G-12
# 4          flat              G-12 Plaza         G-12
#
#                        areaWithType    area  bedRoom  bathroom  balcony  \
# 0    Carpet area: 791 (73.49 sq.m.)   793.0        2         2        1
# 1    Carpet area: 870 (80.83 sq.m.)   870.0        2         2        3
# 2    Carpet area: 946 (87.89 sq.m.)   947.0        3         3        2
# 3  Carpet area: 1321 (122.72 sq.m.)  1322.0        3         4        3
# 4    Carpet area: 354 (32.89 sq.m.)   356.0        1         1        1
#
#    floorNum      facing       agePossession  price_per_sqft  price_in_crore  \
# 0         3  North-East      Moderately Old         23581.0            1.87
# ...

# %%
df['built_up_area'].sample(50)
# Out:
# 555      700.0
# 1802       NaN
# 1158    1053.0
# 3963       NaN
# 2120       NaN
# 1635       NaN
# 2529    1168.0
# 4          NaN
# 3729    1636.0
# 2335       NaN
# 1507       NaN
# 1349       NaN
# 2143       NaN
# 3571    1114.0
# 3413     982.0
# 3514       NaN
# 194      800.0
# 3367       NaN
# 1818       NaN
# 3441     787.0
# 461      800.0
# 2962    2001.0
# 1787       NaN
# 2553       NaN
# 2581       NaN
# 2664       NaN
# 2412     904.0
# 4033       NaN
# 3418    3369.0
# 1937       NaN
# 1427       NaN
# 3881       NaN
# 2076       NaN
# 3679    1028.0
# 1474     600.0
# 704        NaN
# 3108    2670.0
# 1262       NaN
# 2165       NaN
# 2227    1349.0
# 1835       NaN
# 810        NaN
# 3744    2124.0
# 1936    3009.0
# 1998       NaN
# 1574       NaN
# 7          NaN
# 2347     700.0
# 2430       NaN
# 1710       NaN
# Name: built_up_area, dtype: float64

# %%
sns.scatterplot(x = df['area'],y = df['price_in_crore'])
# Out:
# <Axes: xlabel='area', ylabel='price_in_crore'>

# %%
df.drop(columns = ['areaWithType','built_up_area','carpet_area'],inplace = True)

# %%
df.head()
# Out:
#   property_type                 society     location    area  bedRoom  \
# 0          flat  DHA Phase 1 Apartments  DHA Phase 1   793.0        2
# 1          flat          G-15 Residency         G-15   870.0        2
# 2          flat     Bahria Town Heights  Bahria Town   947.0        3
# 3          flat              G-12 Homes         G-12  1322.0        3
# 4          flat              G-12 Plaza         G-12   356.0        1
#
#    bathroom  balcony  floorNum      facing       agePossession  \
# 0         2        1         3  North-East      Moderately Old
# 1         2        3         3        East        New Property
# 2         3        2         6       South  Under Construction
# 3         4        3         9       North        Old Property
# 4         1        1         1        West      Moderately Old
#
#    price_per_sqft  price_in_crore  Study Room  Store Room  Servant Room  \
# 0         23581.0            1.87           0           0             0
# ...

# %%
df.to_csv('Islamabad_properties_outlier_missing.csv',index = False)
