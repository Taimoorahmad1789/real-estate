# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('Islamabad_properties.csv')

# %%
df.sample(5)
# Out:
#                        property_name property_type              society  \
# 1929  4 Bedroom House in Bahria Town         house  bahria town heights
# 106        4 BHK Flat in Bahria Town          flat    Bahria Town Homes
# 3154              1 BHK Flat in G-15          flat           G-15 Plaza
# 3445  5 Bedroom House in DHA Phase 2         house  dha phase 2 enclave
# 2359       1 BHK Flat in DHA Phase 3          flat    DHA Phase 3 Homes
#
#                             areaWithType    area  bedRoom  bathroom  balcony  \
# 1929  Built Up area: 1655 (153.75 sq.m.)  1658.0        4         4        0
# 106      Carpet area: 1452 (134.9 sq.m.)  1455.0        4         3        1
# 3154      Carpet area: 350 (32.52 sq.m.)   351.0        1         1        0
# 3445   Built Up area: 2565 (238.3 sq.m.)  2564.0        5         5        3
# 2359      Carpet area: 350 (32.52 sq.m.)   350.0        1         1        0
#
# ...

# %%
df.shape
# Out:
# (4054, 20)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# property_name      0
# property_type      0
# society            0
# areaWithType       0
# area               0
# bedRoom            0
# bathroom           0
# balcony            0
# additionalRoom     0
# address            0
# floorNum           0
# facing             0
# agePossession      0
# nearbyLocations    0
# description        0
# furnishDetails     0
# features           0
# rating             0
# price_per_sqft     0
# price_in_crore     0
# dtype: int64

# %%
df.insert(loc = 3 , column = 'location',value =
          df['property_name'].str.split('in').str.get(1).
              str.replace('Islamabad','').
              str.strip())

# %%
# df['property_name'].str.split('in').str.get(1).str.replace('Islamabad','').  str.strip()

# %%
df.head()
# Out:
#                property_name property_type                 society  \
# 0  2 BHK Flat in DHA Phase 1          flat  DHA Phase 1 Apartments
# 1         2 BHK Flat in G-15          flat          G-15 Residency
# 2  3 BHK Flat in Bahria Town          flat     Bahria Town Heights
# 3         3 BHK Flat in G-12          flat              G-12 Homes
# 4         1 BHK Flat in G-12          flat              G-12 Plaza
#
#       location                      areaWithType    area  bedRoom  bathroom  \
# 0  DHA Phase 1    Carpet area: 791 (73.49 sq.m.)   793.0        2         2
# 1         G-15    Carpet area: 870 (80.83 sq.m.)   870.0        2         2
# 2  Bahria Town    Carpet area: 946 (87.89 sq.m.)   947.0        3         3
# 3         G-12  Carpet area: 1321 (122.72 sq.m.)  1322.0        3         4
# 4         G-12    Carpet area: 354 (32.89 sq.m.)   356.0        1         1
#
#    balcony additionalRoom                                      address  \
# ...

# %%
df['location'].value_counts()
# Out:
# location
# I-8               198
# G-12              192
# G-10              184
# Margalla Hills    184
# E-11              184
# DHA Phase 1       182
# G-6               181
# Bahria Town       178
# F-11              177
# G-14              175
# G-9               175
# F-8               174
# F-5               174
# G-11              173
# DHA Phase 3       171
# G-15              169
# F-7               169
# DHA Phase 2       165
# G-13              165
# F-10              161
# E-7               160
# F-6               157
# Gulzar-e-Quaid     57
# Rawalp             55
# Chaklala           53
# Sadiqabad          41
# Name: count, dtype: int64

# %%
df.drop(columns = ['property_name','address','description','rating'],inplace = True)

# %%
df.head()
# Out:
#   property_type                 society     location  \
# 0          flat  DHA Phase 1 Apartments  DHA Phase 1
# 1          flat          G-15 Residency         G-15
# 2          flat     Bahria Town Heights  Bahria Town
# 3          flat              G-12 Homes         G-12
# 4          flat              G-12 Plaza         G-12
#
#                        areaWithType    area  bedRoom  bathroom  balcony  \
# 0    Carpet area: 791 (73.49 sq.m.)   793.0        2         2        1
# 1    Carpet area: 870 (80.83 sq.m.)   870.0        2         2        3
# 2    Carpet area: 946 (87.89 sq.m.)   947.0        3         3        2
# 3  Carpet area: 1321 (122.72 sq.m.)  1322.0        3         4        3
# 4    Carpet area: 354 (32.89 sq.m.)   356.0        1         1        1
#
#   additionalRoom  floorNum      facing       agePossession  \
# 0    Prayer Room         3  North-East    5 to 10 Year Old
# 1     Study Room         3        East     0 to 1 Year Old
# ...

# %%
df.to_csv('Islamabad_properties_cleaned_v1.csv',index = False)
